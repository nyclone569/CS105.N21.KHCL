# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Mounted at /content/drive

# %%
car_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/Cars_HaarCascade/cas3.xml')


img = cv2.imread('/content/drive/MyDrive/Cars_Img.jpg')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

cars = car_cascade.detectMultiScale(gray, 1.1,4)

for (x,y,w,h) in cars:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

cv2_imshow(img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=500x333 at 0x7FF4A218B7D0>
# -1
